# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
import SPARQLWrapper
#import JSON
def get_entity_for_musician(artist):
    # YAGO SPARQL endpoint
    endpoint_url = "https://yago-knowledge.org/sparql/query"

    # Randomly select an artist from the list
    artist = artist.lower()

    # SPARQL query template
    query_template = f"""
    PREFIX yago: <http://yago-knowledge.org/resource/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX schema: <http://schema.org/>

    SELECT DISTINCT ?entity ?influencedBy WHERE {{
      {{
        # ?entity a ?type ;
                rdfs:label ?label .
        FILTER(CONTAINS(LCASE(STR(?label)), \"{artist}\")).
        # ?type rdfs:subClassOf* schema:MusicGroup .
      }}
      UNION
      {{
        # ?entity a yago:Musician ;
                rdfs:label ?label .
        FILTER(CONTAINS(LCASE(STR(?label)), \"{artist}\")).
      }}
      UNION      
      {{
        # ?entity a ?type ;
                rdfs:label ?label .
        FILTER(CONTAINS(LCASE(STR(?label)), \"{artist}\")).
        # ?type rdfs:subClassOf* yago:Musician .
      }}
      OPTIONAL {{
        # ?entity schema:influencedBy ?influencedBy .
      }}
    }} LIMIT 10
    """

    # Setup SPARQL
    sparql = SPARQLWrapper.SPARQLWrapper(endpoint_url)
    sparql.setQuery(query_template)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query
        results = sparql.query().convert()
        bindings = results["results"]["bindings"]
        results = []
        for binding in  bindings:
            entity = binding["entity"]["value"]
            #label = binding.get("label", {}).get("value", "Unknown Label")
            type_ = binding.get("type", {}).get("value", "Unknown Type")
            influenced_by = binding.get("influencedBy", {}).get("value", None)
            results.append( {
                "artist": artist,
                "entity": entity,
               # "label": label,
                "type": type_,
                "influenced_by": influenced_by
            })
        return results

    except Exception as e:
        return None

# %%
def get_songs_by_artist_url(artist_url):
    # YAGO SPARQL endpoint
    endpoint_url = "https://yago-knowledge.org/sparql/query"

    # SPARQL query template
    query_template = f"""
    PREFIX schema: <http://schema.org/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

    SELECT DISTINCT ?entity (SAMPLE(?label) AS ?label) ?type WHERE {{
      # ?entity a ?type ;
              schema:musicBy <{artist_url}> ;
              rdfs:label ?label .
      # ?type rdfs:subClassOf* schema:MusicComposition .
      FILTER(LANG(?label) = "en")
    }} GROUP BY ?entity ?type LIMIT 50
    """

    # Setup SPARQL
    sparql = SPARQLWrapper.SPARQLWrapper(endpoint_url)
    sparql.setQuery(query_template)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query
        results = sparql.query().convert()
        bindings = results["results"]["bindings"]

        songs = []
        for binding in bindings:
            entity = binding.get("entity", {}).get("value", "Unknown Entity")
            label = binding.get("label", {}).get("value", "Unknown Label")
            type_ = binding.get("type", {}).get("value", "Unknown Type")
            songs.append({"entity": entity, "label": label, "type": type_})

        return songs

    except Exception as e:
        print(str(e))
        return None

# %%
def get_label_by_entity_url(entity_url):
    # YAGO SPARQL endpoint
    endpoint_url = "https://yago-knowledge.org/sparql/query"

    # SPARQL query template
    query_template = f"""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

    SELECT ?label WHERE {{
      <{entity_url}> rdfs:label ?label .
      
      FILTER(LANG(?label) = "en")
    }} LIMIT 1
    """

    # Setup SPARQL
    sparql = SPARQLWrapper.SPARQLWrapper(endpoint_url)
    sparql.setQuery(query_template)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query
        results = sparql.query().convert()
        bindings = results["results"]["bindings"]

        if bindings:
            sampled_label = bindings[0].get("label", {}).get("value", None)
            return {"entity": entity_url, "label": sampled_label}
        else:
            return {"entity": entity_url, "label": "No label found."}

    except Exception as e:
        return {"error": str(e)}

# %%
#get_label_by_entity_url("http://yago-knowledge.org/resource/David_Bowie")

# %%
#get_songs_by_artist_url("http://yago-knowledge.org/resource/David_Bowie")

# %%
import random
import numpy as np
def get_recommendations_based_on_influencedBy(artist_str, max_influences = 2):
    results = []
    print("Getting influencedBy entities...")
    getting_items = get_entity_for_musician(artist_str)
    print(getting_items)
    influences = np.unique(list(map(lambda item: item["influenced_by"], [item for item in getting_items if item["influenced_by"] is not None]))).tolist()

    if len(influences) == 0:
        return None
    print(influences)
    influences = random.choices(influences, k=min(max_influences, len(influences)))
    
    print(f"Choosing first {max_influences} artists...")
    for influence in influences:
        print(f"Processing {influence}...")
        dict_item = get_label_by_entity_url(influence)
        songs = get_songs_by_artist_url(influence)
        results.append({"artist":influence, "label":dict_item["label"], "songs":songs})
        
    return results

# %%
def get_randomly_weighted(items, k):
    artists = list(items.keys())
    weights = list(items.values())
    selected = {}

    for _ in range(k):
        total_weight = sum(weights)
        probabilities = [w / total_weight for w in weights]

        chosen_index = random.choices(range(len(artists)), probabilities, k=1)[0]
        selected[artists[chosen_index]] =  weights[chosen_index]

        artists.pop(chosen_index)
        weights.pop(chosen_index)

    return selected
    
def get_recommendarions_based_on_influencedBy_likes_dislikes(likes = [], dislikes = [], max_influences=4, debug=False):
    influencedByCounters  = {}
    results = []
    for artist in likes:
        if debug:
            print(f"Processing liked artist: {artist} ")    
        getting_items = get_entity_for_musician(artist)
        for item in getting_items:
            if item["influenced_by"] is not None:
                print(item)
                if item["influenced_by"] not in influencedByCounters:
                    influencedByCounters[item["influenced_by"]] = 1
                else:
                    influencedByCounters[item["influenced_by"]] += 1
    for artist in dislikes:
        if debug:
            print(f"Processing disliked artist: {artist} ")   
        
        getting_items = get_entity_for_musician(artist)
        for item in getting_items:
            if item["influenced_by"] is not None:
                if item["influenced_by"] in influencedByCounters:
                    influencedByCounters[item["influenced_by"]] -= 1
                    
                    if debug:
                        print(f'{item["influenced_by"]} was penalized')
                    if influencedByCounters[item["influenced_by"]] == 0:
                        del influencedByCounters[item["influenced_by"]]
    if len(influencedByCounters) == 0:
        return None
    print(influencedByCounters)
    influenced_by_dict = get_randomly_weighted(influencedByCounters,max_influences)    
    for influence, count in influenced_by_dict.items():
        if debug:
            print(f"Processing {influence}...")
        dict_item = get_label_by_entity_url(influence)
        songs = get_songs_by_artist_url(influence)
        results.append({"artist":influence, "label":dict_item["label"], "songs":songs, "weight":count})
    return sorted(results, key=lambda item: item["weight"], reverse=True)

# %%
#likes = ["beatles", "Bruno Mars", "Michael Jackson", "Britney Spears"]
likes = ["Britney Spears", "Bruno Mars"]
dislikes = ["Sam Smith"]
songs = get_recommendarions_based_on_influencedBy_likes_dislikes(likes, dislikes, max_influences=2, debug=True)
# Out:
# Processing liked artist: Britney Spears
# {'artist': 'britney spears', 'entity': 'http://yago-knowledge.org/resource/Britney_Spears', 'type': 'Unknown Type', 'influenced_by': 'http://yago-knowledge.org/resource/Michael_Jackson'}
# {'artist': 'britney spears', 'entity': 'http://yago-knowledge.org/resource/Britney_Spears', 'type': 'Unknown Type', 'influenced_by': 'http://yago-knowledge.org/resource/Madonna'}
# {'artist': 'britney spears', 'entity': 'http://yago-knowledge.org/resource/Britney_Spears', 'type': 'Unknown Type', 'influenced_by': 'http://yago-knowledge.org/resource/Janet_Jackson'}
# {'artist': 'britney spears', 'entity': 'http://yago-knowledge.org/resource/Britney_Spears', 'type': 'Unknown Type', 'influenced_by': 'http://yago-knowledge.org/resource/Whitney_Houston'}
# Processing liked artist: Bruno Mars
# {'artist': 'bruno mars', 'entity': 'http://yago-knowledge.org/resource/Bruno_Mars', 'type': 'Unknown Type', 'influenced_by': 'http://yago-knowledge.org/resource/Michael_Jackson'}
# Processing disliked artist: Sam Smith
# http://yago-knowledge.org/resource/Whitney_Houston was penalized
# {'http://yago-knowledge.org/resource/Michael_Jackson': 2, 'http://yago-knowledge.org/resource/Madonna': 1, 'http://yago-knowledge.org/resource/Janet_Jackson': 1}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 4
#       2 likes = ["Britney Spears", "Bruno Mars"]
#       3 dislikes = ["Sam Smith"]
# ----> 4 songs = get_recommendarions_based_on_influencedBy_likes_dislikes(likes, dislikes, max_influences=4, debug=True)
#
# Cell In[8], line 49, in get_recommendarions_based_on_influencedBy_likes_dislikes(likes, dislikes, max_influences, debug)
#      47     return None
#      48 print(influencedByCounters)
# ---> 49 influenced_by_dict = get_randomly_weighted(influencedByCounters,max_influences)
#      50 for influence, count in influenced_by_dict.items():
#      51     if debug:
#
# Cell In[8], line 10, in get_randomly_weighted(items, k)
#       7 total_weight = sum(weights)
#       8 probabilities = [w / total_weight for w in weights]
# ---> 10 chosen_index = random.choices(range(len(artists)), probabilities, k=1)[0]
#      11 selected[artists[chosen_index]] =  weights[chosen_index]
#      13 artists.pop(chosen_index)
#
# File ~/anaconda3/envs/msc_artificial_intelligence/lib/python3.12/random.py:481, in Random.choices(self, population, weights, cum_weights, k)
#     479 if len(cum_weights) != n:
#     480     raise ValueError('The number of weights does not match the population')
# --> 481 total = cum_weights[-1] + 0.0   # convert to float
#     482 if total <= 0.0:
#     483     raise ValueError('Total of weights must be greater than zero')
#
# IndexError: list index out of range

# %%
songs
# Out:
# [{'artist': 'http://yago-knowledge.org/resource/Elvis_Presley',
#   'label': 'Elvis Presley',
#   'songs': [{'entity': 'http://yago-knowledge.org/resource/Heartbreak_Hotel',
#     'label': 'Heartbreak Hotel',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Love_Me_Tender__u0028_song_u0029_',
#     'label': 'Love Me Tender',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/All_Shook_Up__u0028_musical_u0029_',
#     'label': 'All Shook Up',
#     'type': 'http://yago-knowledge.org/resource/Dramatico-Musical_Work_Q58483083'}],
#   'weight': 1},
#  {'artist': 'http://yago-knowledge.org/resource/Chuck_Berry',
#   'label': 'Chuck Berry',
#   'songs': [{'entity': 'http://yago-knowledge.org/resource/Johnny_B_u002E__Goode',
#     'label': 'Johnny B. Goode',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Rock_and_Roll_Music__u0028_song_u0029_',
#     'label': 'Rock and Roll Music',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Roll_Over_Beethoven',
#     'label': 'Roll Over Beethoven',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Sweet_Little_Sixteen',
#     'label': 'Sweet Little Sixteen',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Come_On__u0028_Chuck_Berry_song_u0029_',
#     'label': 'Come On',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/No_Particular_Place_to_Go',
#     'label': 'No Particular Place to Go',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/You_Never_Can_Tell__u0028_song_u0029_',
#     'label': 'You Never Can Tell',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/Almost_Grown__u0028_song_u0029_',
#     'label': 'Almost Grown',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Little_Queenie',
#     'label': 'Little Queenie',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Surfin_u0027__U_u002E_S_u002E_A_u002E_',
#     'label': "Surfin' U.S.A.",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Memphis_u002C__Tennessee__u0028_song_u0029_',
#     'label': 'Memphis, Tennessee',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Around_and_Around',
#     'label': 'Around and Around',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Back_in_the_U_u002E_S_u002E_A_u002E_',
#     'label': 'Back in the U.S.A.',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'}],
#   'weight': 1},
#  {'artist': 'http://yago-knowledge.org/resource/Michael_Jackson',
#   'label': 'Michael Jackson',
#   'songs': [{'entity': 'http://yago-knowledge.org/resource/The_Way_You_Make_Me_Feel',
#     'label': 'The Way You Make Me Feel',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Give_In_to_Me',
#     'label': 'Give In to Me',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Leave_Me_Alone__u0028_Michael_Jackson_song_u0029_',
#     'label': 'Leave Me Alone',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Can_You_Feel_It__u0028_The_Jacksons_song_u0029_',
#     'label': 'Can You Feel It',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Don_u0027_t_Stop__u0027_Til_You_Get_Enough',
#     'label': "Don't Stop 'Til You Get Enough",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Blood_on_the_Dance_Floor__u0028_song_u0029_',
#     'label': 'Blood on the Dance Floor',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Remember_the_Time',
#     'label': 'Remember the Time',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Childhood__u0028_Michael_Jackson_song_u0029_',
#     'label': 'Childhood',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Billie_Jean',
#     'label': 'Billie Jean',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/D_u002E_S_u002E___u0028_song_u0029_',
#     'label': 'D.S.',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/The_Girl_Is_Mine',
#     'label': 'The Girl Is Mine',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Dangerous__u0028_Michael_Jackson_song_u0029_',
#     'label': 'Dangerous',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Bad__u0028_Michael_Jackson_song_u0029_',
#     'label': 'Bad',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Can_u0027_t_Let_Her_Get_Away',
#     'label': "Can't Let Her Get Away",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Earth_Song',
#     'label': 'Earth Song',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/We_Are_the_World',
#     'label': 'We Are the World',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/I_Just_Can_u0027_t_Stop_Loving_You',
#     'label': "I Just Can't Stop Loving You",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Liberian_Girl',
#     'label': 'Liberian Girl',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Scream__u0028_Michael_Jackson_and_Janet_Jackson_song_u0029_',
#     'label': 'Scream',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Will_You_Be_There',
#     'label': 'Will You Be There',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Do_the_Bartman',
#     'label': 'Do the Bartman',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/Dirty_Diana',
#     'label': 'Dirty Diana',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Beat_It',
#     'label': 'Beat It',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Heal_the_World',
#     'label': 'Heal the World',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/You_Rock_My_World',
#     'label': 'You Rock My World',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/Who_Is_It__u0028_Michael_Jackson_song_u0029_',
#     'label': 'Who Is It',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Speed_Demon__u0028_song_u0029_',
#     'label': 'Speed Demon',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/A_Place_with_No_Name',
#     'label': 'A Place with No Name',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/This_Is_It__u0028_Michael_Jackson_song_u0029_',
#     'label': 'This Is It',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Breaking_News__u0028_song_u0029_',
#     'label': 'Breaking News',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Breaking_News__u0028_song_u0029_',
#     'label': 'Breaking News',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/Love_Never_Felt_So_Good',
#     'label': 'Love Never Felt So Good',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/Black_or_White',
#     'label': 'Black or White',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/In_the_Closet',
#     'label': 'In the Closet',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/MJ_the_Musical',
#     'label': 'MJ: The Musical',
#     'type': 'http://yago-knowledge.org/resource/Dramatico-Musical_Work_Q58483083'},
#    {'entity': 'http://yago-knowledge.org/resource/Another_Part_of_Me',
#     'label': 'Another Part of Me',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/What_More_Can_I_Give',
#     'label': 'What More Can I Give',
#     'type': 'http://yago-knowledge.org/resource/Song'},
#    {'entity': 'http://yago-knowledge.org/resource/Jam__u0028_Michael_Jackson_song_u0029_',
#     'label': 'Jam',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Working_Day_and_Night',
#     'label': 'Working Day and Night',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Smooth_Criminal',
#     'label': 'Smooth Criminal',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Wanna_Be_Startin_u0027__Somethin_u0027_',
#     'label': "Wanna Be Startin' Somethin'",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'}],
#   'weight': 1},
#  {'artist': 'http://yago-knowledge.org/resource/Bob_Dylan',
#   'label': 'Bob Dylan',
#   'songs': [{'entity': 'http://yago-knowledge.org/resource/The_Ballad_of_Frankie_Lee_and_Judas_Priest',
#     'label': 'The Ballad of Frankie Lee and Judas Priest',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Masters_of_War',
#     'label': 'Masters of War',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Most_Likely_You_Go_Your_Way_and_I_u0027_ll_Go_Mine',
#     'label': "Most Likely You Go Your Way and I'll Go Mine",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/I_Am_a_Lonesome_Hobo',
#     'label': 'I Am a Lonesome Hobo',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Temporary_Like_Achilles',
#     'label': 'Temporary Like Achilles',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/The_Times_They_Are_a-Changin_u0027___u0028_song_u0029_',
#     'label': "Times They Are a-Changin'",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/I_Pity_the_Poor_Immigrant',
#     'label': 'I Pity the Poor Immigrant',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Love_Is_Just_a_Four-Letter_Word',
#     'label': 'Love Is Just a Four-Letter Word',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Pressing_On__u0028_Bob_Dylan_song_u0029_',
#     'label': 'Pressing On',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Sara__u0028_Bob_Dylan_song_u0029_',
#     'label': 'Sara',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Boots_of_Spanish_Leather',
#     'label': 'Boots of Spanish Leather',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Gates_of_Eden__u0028_song_u0029_',
#     'label': 'Gates of Eden',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/I_Don_u0027_t_Believe_You__u0028_She_Acts_Like_We_Never_Have_Met_u0029_',
#     'label': "I Don't Believe You (She Acts Like We Never Have Met)",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Workingman_u0027_s_Blues',
#     'label': "Workingman's Blues No.2",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Girl_from_the_North_Country',
#     'label': 'Girl from the North Country',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Make_You_Feel_My_Love',
#     'label': 'Make You Feel My Love',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Bob_Dylan_u0027_s_Dream',
#     'label': "Bob Dylan's Dream",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Leopard-Skin_Pill-Box_Hat',
#     'label': 'Leopard-Skin Pill-Box Hat',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Highway_61_Revisited__u0028_song_u0029_',
#     'label': 'Highway 61 Revisited',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Mixed-Up_Confusion',
#     'label': 'Mixed-Up Confusion',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/It_Takes_a_Lot_to_Laugh_u002C__It_Takes_a_Train_to_Cry',
#     'label': 'It Takes a Lot to Laugh, It Takes a Train to Cry',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/As_I_Went_Out_One_Morning',
#     'label': 'As I Went Out One Morning',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Drifter_u0027_s_Escape',
#     'label': "Drifter's Escape",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/4th_Time_Around',
#     'label': '4th Time Around',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Wigwam__u0028_Bob_Dylan_song_u0029_',
#     'label': 'Wigwam',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/The_Wicked_Messenger',
#     'label': 'The Wicked Messenger',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/When_He_Returns',
#     'label': 'When He Returns',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/I_Shall_Be_Free',
#     'label': 'I Shall Be Free',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Where_Are_You_Tonight_u003F___u0028_Journey_Through_Dark_Heat_u0029_',
#     'label': 'Where Are You Tonight? (Journey Through Dark Heat)',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Obviously_5_Believers',
#     'label': 'Obviously 5 Believers',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Positively_4th_Street',
#     'label': 'Positively 4th Street',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Visions_of_Johanna',
#     'label': 'Visions of Johanna',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/It_u0027_s_All_Over_Now_u002C__Baby_Blue',
#     'label': "It's All Over Now, Baby Blue",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Don_u0027_t_Think_Twice_u002C__It_u0027_s_All_Right',
#     'label': "Don't Think Twice, It's All Right",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/It_Ain_u0027_t_Me_Babe',
#     'label': "It Ain't Me Babe",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/The_Lonesome_Death_of_Hattie_Carroll',
#     'label': 'The Lonesome Death of Hattie Carroll',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/I_Shall_Be_Released',
#     'label': 'I Shall Be Released',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Restless_Farewell',
#     'label': 'Restless Farewell',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Just_Like_Tom_Thumb_u0027_s_Blues',
#     'label': "Just Like Tom Thumb's Blues",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Tryin_u0027__to_Get_to_Heaven',
#     'label': "Tryin' to Get to Heaven",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Love_Minus_Zero_u002F_No_Limit',
#     'label': 'Love Minus Zero/No Limit',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/She_Belongs_to_Me',
#     'label': 'She Belongs to Me',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Heading_for_the_Light',
#     'label': 'Heading for the Light',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Precious_Angel',
#     'label': 'Precious Angel',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/To_Ramona',
#     'label': 'To Ramona',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Tweeter_and_the_Monkey_Man',
#     'label': 'Tweeter and the Monkey Man',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Talkin_u0027__World_War_III_Blues',
#     'label': 'Talking World War III Blues',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Down_the_Highway__u0028_song_u0029_',
#     'label': 'Down the Highway',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Heart_of_Mine__u0028_Bob_Dylan_song_u0029_',
#     'label': 'Heart of Mine',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/From_a_Buick_6',
#     'label': 'From a Buick 6',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'}],
#   'weight': 1},
#  {'artist': 'http://yago-knowledge.org/resource/Ludwig_van_Beethoven',
#   'label': 'Ludwig van Beethoven',
#   'songs': [{'entity': 'http://yago-knowledge.org/resource/Impressing_the_Czar',
#     'label': 'Impressing the Czar',
#     'type': 'http://yago-knowledge.org/resource/Ballet_Q15079786'},
#    {'entity': 'http://yago-knowledge.org/resource/Symphony_No_u002E__9__u0028_Beethoven_u0029_',
#     'label': 'Symphony No. 9',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__10__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 10',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__12__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 12',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__28__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 28',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__9__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 9',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/String_Quartet_No_u002E__16__u0028_Beethoven_u0029_',
#     'label': 'String Quartet No. 16',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Beethoven_Romance',
#     'label': 'Beethoven Romance',
#     'type': 'http://yago-knowledge.org/resource/Ballet_Q15079786'},
#    {'entity': 'http://yago-knowledge.org/resource/Three_Piano_Sonatas_u002C__WoO_47__u0028_Beethoven_u0029_',
#     'label': 'Three Piano Sonatas, WoO 47',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Violin_Concerto_in_C__u0028_Beethoven_u0029_',
#     'label': 'Violin Concerto in C',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Concerto_No_u002E__5__u0028_Beethoven_u0029_',
#     'label': 'Piano Concerto No. 5',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/String_Quartet_No_u002E__9__u0028_Beethoven_u0029_',
#     'label': 'String Quartet No. 9',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Turkish_March__u0028_Beethoven_u0029_',
#     'label': 'Turkish March',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Cello_Sonata_No_u002E__3__u0028_Beethoven_u0029_',
#     'label': 'Cello Sonata No. 3',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Choral_Fantasy__u0028_Beethoven_u0029_',
#     'label': 'Choral Fantasy',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Wellington_u0027_s_Victory',
#     'label': "Wellington's Victory",
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Rise_u002C__O_Voices_of_Rhodesia',
#     'label': 'Rise, O Voices of Rhodesia',
#     'type': 'http://yago-knowledge.org/resource/National_anthem'},
#    {'entity': 'http://yago-knowledge.org/resource/Anthem_of_Europe',
#     'label': 'Anthem of Europe',
#     'type': 'http://yago-knowledge.org/resource/National_anthem'},
#    {'entity': 'http://yago-knowledge.org/resource/Four_Bagatelles',
#     'label': 'Four Bagatelles',
#     'type': 'http://yago-knowledge.org/resource/Ballet_Q15079786'},
#    {'entity': 'http://yago-knowledge.org/resource/Variations_in_E-flat_major__u0028_Beethoven_u0029_',
#     'label': 'Variations on an original theme in E-flat major',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Es_ist_vollbracht__u0028_Beethoven_u0029_',
#     'label': 'Es ist vollbracht',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__11__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 11',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__15__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 15',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__21__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 21',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__23__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 23',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/String_Quartet_No_u002E__11__u0028_Beethoven_u0029_',
#     'label': 'String Quartet No. 11',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/The_Hymn_of_Joy',
#     'label': 'Joyful, Joyful We Adore Thee',
#     'type': 'http://yago-knowledge.org/resource/Christian_Hymn_Q856713'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__25__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 25',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__3__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 3',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__32__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 32',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Rondo_for_Piano_and_Orchestra__u0028_Beethoven_u0029_',
#     'label': 'Rondo for piano and orchestra',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Symphony_No_u002E__1__u0028_Beethoven_u0029_',
#     'label': 'Symphony No. 1',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Symphony_No_u002E__2__u0028_Beethoven_u0029_',
#     'label': 'Symphony No. 2',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/String_Quartet_No_u002E__4__u0028_Beethoven_u0029_',
#     'label': 'String Quartet No. 4',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Missa_solemnis__u0028_Beethoven_u0029_',
#     'label': 'Missa Solemnis',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/The_Consecration_of_the_House__u0028_overture_u0029_',
#     'label': 'The Consecration of the House',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Violin_Sonata_No_u002E__4__u0028_Beethoven_u0029_',
#     'label': 'Violin Sonata No. 4',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Quintet_for_Piano_and_Winds__u0028_Beethoven_u0029_',
#     'label': 'Quintet for Piano and Winds',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Trio_for_piano_u002C__flute_and_bassoon__u0028_Beethoven_u0029_',
#     'label': 'Trio for Piano, Flute and Bassoon',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Quintettsatz_in_D_minor__u0028_Beethoven_u0029_',
#     'label': 'Quintettsatz in D minor',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Seufzer_eines_Ungeliebten__u2013__Gegenliebe',
#     'label': 'Gegenliebe',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/String_Quintet_u002C__Op_u002E__29__u0028_Beethoven_u0029_',
#     'label': 'String Quintet, Op. 29',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Horn_Sonata__u0028_Beethoven_u0029_',
#     'label': 'Horn Sonata',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__13__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 13',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__16__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 16',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__2__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 2',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Sonata_No_u002E__29__u0028_Beethoven_u0029_',
#     'label': 'Piano Sonata No. 29',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/String_Quartet_No_u002E__1__u0028_Beethoven_u0029_',
#     'label': 'String Quartet No. 1',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Piano_Concerto_No_u002E__6__u0028_Beethoven_u0029_',
#     'label': 'Piano Concerto No. 6',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'},
#    {'entity': 'http://yago-knowledge.org/resource/Flute_Sonata_in_B-flat_major__u0028_attributed_to_Beethoven_u0029_',
#     'label': 'Flute Sonata in B-flat major',
#     'type': 'http://yago-knowledge.org/resource/Musical_Work_U002F_Composition_Q105543609'}],
#   'weight': 1}]
